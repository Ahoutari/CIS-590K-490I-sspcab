# %%
#!pip install -r "C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt" --user

# %%
#!pip install Pillow==9.0.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
import tensorflow as tf

tf.config.run_functions_eagerly(True)

from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random

print(tf.__version__)
# Out:
# 2.11.0

# %%
class SSPCAB(tf.keras.layers.Layer):
    def __init__(self, kernel_dim, dilation, filters, reduction_ratio=8, name=None, **kwargs):
        super(SSPCAB, self).__init__(name=name, **kwargs)
        
        self.kernel_dim = kernel_dim
        self.dilation = dilation
        self.filters = filters
        self.reduction_ratio = reduction_ratio
        
        self.pad = kernel_dim + dilation
        self.border_input = kernel_dim + 2*dilation + 1
        
        self.sspcab_1 = tf.keras.layers.Conv2D(
            filters=filters, kernel_size=kernel_dim, activation=tf.nn.relu, name=f'{name}_1')
        
        self.sspcab_3 = tf.keras.layers.Conv2D(
            filters=filters, kernel_size=kernel_dim, activation=tf.nn.relu, name=f'{name}_3')
        
        self.sspcab_7 = tf.keras.layers.Conv2D(
            filters=filters, kernel_size=kernel_dim, activation=tf.nn.relu, name=f'{name}_7')
        
        self.sspcab_9 = tf.keras.layers.Conv2D(
            filters=filters, kernel_size=kernel_dim, activation=tf.nn.relu, name=f'{name}_9')
    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'kernel_dim': self.kernel_dim,
            'dilation': self.dilation,
            'filters': self.filters,
            'reduction_ratio': self.reduction_ratio,
            'name': self.name
        })
        return config
        
    def se_block(self, input_x, in_channels, ratio):
        squeeze = tf.reduce_mean(input_x, axis=[1, 2])
        
        excitation = tf.keras.layers.Dense(use_bias=True, units=in_channels / ratio, name='sspcab_se_1')(squeeze)
        excitation = tf.nn.relu(excitation)
        excitation = tf.keras.layers.Dense(use_bias=True, units=in_channels, name='sspcab_se_2')(excitation)
        excitation = tf.nn.sigmoid(excitation)

        excitation = tf.reshape(excitation, [-1, 1, 1, in_channels])
        scale = input_x * excitation
        
        return scale
        
    def call(self, inputs, *args, **kwargs):
        sspcab_input = tf.pad(inputs, tf.constant([[0, 0], [self.pad, self.pad], [self.pad, self.pad], [0, 0]]), "REFLECT")
        
        out_1 = self.sspcab_1(sspcab_input[:, :-self.border_input, :-self.border_input, :])
        out_3 = self.sspcab_3(sspcab_input[:, self.border_input:, :-self.border_input, :])
        out_7 = self.sspcab_7(sspcab_input[:, :-self.border_input, self.border_input:, :])
        out_9 = self.sspcab_9(sspcab_input[:, self.border_input:, self.border_input:, :])
        
        sspcab_out = out_1 + out_3 + out_7 + out_9

        se_out = self.se_block(sspcab_out, self.filters, self.reduction_ratio)
        
        cost_sspcab = tf.square(inputs - se_out)
        loss = 0.1 * tf.reduce_mean(cost_sspcab)
                
        self.add_loss(loss)

        return se_out

# %%
#Size of our input images
SIZE = 128

from keras.preprocessing.image import ImageDataGenerator

batch_size = 32
datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    'datasets/capsule/train/',
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    class_mode='input'
    )

validation_generator = datagen.flow_from_directory(
    'datasets/capsule/test/good',
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    class_mode='input'
    )

anomaly_generator = datagen.flow_from_directory(
    'datasets/capsule/test/defective/',
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    class_mode='input'
    )
# Out:
# Found 219 images belonging to 1 classes.
# Found 23 images belonging to 1 classes.
# Found 109 images belonging to 5 classes.

# %% [markdown]
# ### Building the basic encoder

# %%
model = Sequential()

# Encoder 
"""
Each encoder is composed of three convolutional (conv)
layers, each followed by a max-pooling layer with a filter
size of 2 × 2 applied at a stride of 2. The conv layers are
formed of 3 × 3 filters. Each conv layer is followed by
Rectified Linear Units (ReLU) [70] as the activation function.
The first two conv layers consist of 32 filters, while the
third layer consists of 16 filters. The latent representation
is composed of 16 activation maps of size 8 × 8.
"""

model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(SIZE, SIZE, 3)))
model.add(MaxPooling2D((2, 2), padding='same', strides=2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same', strides=2))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))

# Decoder
"""
Each decoder starts with an upsampling layer, increasing
the spatial support of the activation maps by a factor of
2×. The upsampling operation is based on nearest neighbor
interpolation. After upsampling, we apply a conv layer with
16 filters of 3 × 3. The first upsampling and conv block
is followed by another two upsampling and conv blocks.
The last conv layer of an appearance decoder is formed of
a single conv filter, while the last conv layer of a motion
decoder is formed of two filters. In both cases, the number
of filters in the last conv layer is chosen such that the size of
the output matches the size of the input
"""
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(SSPCAB(name='sspcab', filters=64, kernel_dim=1, dilation=1, reduction_ratio=8))
model.add(Conv2D(3, (3, 3), activation='sigmoid', padding='same'))

# %% [markdown]
# ### Training the encoder

# %%
# Start with adam optimizer
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])

# %%
#Fit the model. 
history = model.fit(
        train_generator,
        steps_per_epoch= 219 // batch_size,
        epochs=10,
        shuffle = True)
# Out:
# Epoch 1/10
# C:\Users\madhu\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\structured_function.py:256: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 6/6 [==============================] - 36s 6s/step - loss: 0.0716 - mse: 0.0702
# Epoch 2/10
# 6/6 [==============================] - 36s 6s/step - loss: 0.0493 - mse: 0.0462
# Epoch 3/10
# 6/6 [==============================] - 36s 6s/step - loss: 0.0415 - mse: 0.0400
# Epoch 4/10
# 6/6 [==============================] - 35s 6s/step - loss: 0.0337 - mse: 0.0327
# Epoch 5/10
# 6/6 [==============================] - 40s 6s/step - loss: 0.0272 - mse: 0.0263
# Epoch 6/10
# 6/6 [==============================] - 40s 6s/step - loss: 0.0234 - mse: 0.0228
# Epoch 7/10
# 6/6 [==============================] - 56s 9s/step - loss: 0.0212 - mse: 0.0207
# Epoch 8/10
# 6/6 [==============================] - 41s 7s/step - loss: 0.0200 - mse: 0.0196
# Epoch 9/10
# 6/6 [==============================] - 39s 6s/step - loss: 0.0185 - mse: 0.0181
# Epoch 10/10
# 6/6 [==============================] - 38s 6s/step - loss: 0.0172 - mse: 0.0168

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['mse']
mse = history.history['loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, mse, 'r', label='MSE')
plt.title('Training and MSE')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# plt.plot(history.history['mse'])
# plt.plot(history.history['loss'])
# plt.title('Training and mse')
# plt.ylabel('loss')
# plt.xlabel('epochs')
# plt.legend(['training loss', 'val loss'], loc='upper left')
# plt.show()

# %%
#Save model
model.save('models/capsule/autoencoder_capsule.h5')

# %% [markdown]
# ### Load the trained model

# %%
tf.data.experimental.enable_debug_mode()

model = tf.keras.models.load_model('models/capsule/autoencoder_capsule.h5', custom_objects={'SSPCAB': SSPCAB})

# %%
# Get all batches generated by the datagen and pick a batch for prediction
#Just to test the model. 
data_batch = []  #Capture all training batches as a numpy array
img_num = 0
while img_num <= train_generator.batch_index:   #gets each generated batch of size batch_size
    data = train_generator.next()
    data_batch.append(data[0])
    img_num = img_num + 1

predicted = model.predict(data_batch[0])  #Predict on the first batch of images
# Out:
# 1/1 [==============================] - 1s 1s/step

# %% [markdown]
# ### Checking how the autoecoder works

# %%
#Sanity check, view few images and corresponding reconstructions
image_number = random.randint(0, predicted.shape[0])
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(data_batch[0][image_number])
plt.subplot(122)
plt.imshow(predicted[image_number])
plt.show()

# %% [markdown]
# ### Checking the reconstruction error

# %%
#Let us examine the reconstruction error between our validation data (good/normal images)
# and the anomaly images
validation_error = model.evaluate(validation_generator)
anomaly_error = model.evaluate(anomaly_generator)


print("Recon. error for the validation (normal) data is: ", validation_error)
print("Recon. error for the anomaly data is: ", anomaly_error)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.0144 - mse: 0.0141
# 4/4 [==============================] - 10s 2s/step - loss: 0.0140 - mse: 0.0137
# Recon. error for the validation (normal) data is:  [0.014395429752767086, 0.014069193042814732]
# Recon. error for the anomaly data is:  [0.014028208330273628, 0.013680476695299149]

# %% [markdown]
# ### Building a feature extractor from the trained autoencoder

# %%
#Let us extract (or build) the encoder network, with trained weights.
#This is used to get the compressed output (latent space) of the input image. 
#The compressed output is then used to calculate the KDE

encoder_model = Sequential()

encoder_model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(SIZE, SIZE, 3),  trainable=False, weights=model.layers[0].get_weights()))
encoder_model.add(MaxPooling2D((2, 2), padding='same', strides=2))
encoder_model.add(Conv2D(32, (3, 3), activation='relu', padding='same', trainable=False, weights=model.layers[2].get_weights()))
encoder_model.add(MaxPooling2D((2, 2), padding='same', strides=2))
encoder_model.add(Conv2D(16, (3, 3), activation='relu', padding='same', trainable=False, weights=model.layers[4].get_weights()))

encoder_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 128, 128, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 32)        9248
#
#  max_pooling2d_3 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 16)        4624
#
# =================================================================
# Total params: 14,768
# Trainable params: 0
# Non-trainable params: 14,768
# _________________________________________________________________

# %%
# import sys
# !{sys.executable} -m pip install sklearn

# %%
# Calculate KDE using sklearn

from sklearn.neighbors import KernelDensity

#Get encoded output of input images = Latent space
encoded_images = encoder_model.predict(train_generator)

# Flatten the encoder output because KDE from sklearn takes 1D vectors as input
encoder_output_shape = encoder_model.output_shape #Here, we have 16x16x16
out_vector_shape = encoder_output_shape[1]*encoder_output_shape[2]*encoder_output_shape[3]

encoded_images_vector = [np.reshape(img, (out_vector_shape)) for img in encoded_images]

#Fit KDE to the image latent data
kde = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(encoded_images_vector)
# Out:
# 7/7 [==============================] - 10s 1s/step

# %% [markdown]
# ### Calculate Density & Recon Error to find the best threshold

# %%
#Calculate density and reconstruction error to find their means values for
#good and anomaly images. 
#We use these mean and sigma to set thresholds. 
def calc_density_and_recon_error(batch_images):
    density_list=[]
    recon_error_list=[]
    for im in range(0, batch_images.shape[0]-1):
        
        img  = batch_images[im]
        img = img[np.newaxis, :,:,:]
        encoded_img = encoder_model.predict([[img]]) # Create a compressed version of the image using the encoder
        encoded_img = [np.reshape(img, (out_vector_shape)) for img in encoded_img] # Flatten the compressed image
        density = kde.score_samples(encoded_img)[0] # get a density score for the new image
        reconstruction = model.predict([[img]])
        reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)[0]
        density_list.append(density)
        recon_error_list.append(reconstruction_error)
        
    average_density = np.mean(np.array(density_list))  
    stdev_density = np.std(np.array(density_list)) 
    
    average_recon_error = np.mean(np.array(recon_error_list))  
    stdev_recon_error = np.std(np.array(recon_error_list)) 
    
    return average_density, stdev_density, average_recon_error, stdev_recon_error

# %%
#Get average and std dev. of density and recon. error for uninfected and anomaly (parasited) images. 
#For this let us generate a batch of images for each. 
train_batch = train_generator.next()[0]
anomaly_batch = anomaly_generator.next()[0]

normal_values = calc_density_and_recon_error(train_batch)
anomaly_values = calc_density_and_recon_error(anomaly_batch)

print("Normal values: ", normal_values)
print("Anomaly values: ", anomaly_values)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 153ms/step - loss: 0.0212 - mse: 0.0208
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0179 - mse: 0.0176
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0195 - mse: 0.0192
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 143ms/step - loss: 0.0189 - mse: 0.0186
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0209 - mse: 0.0206
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0193 - mse: 0.0190
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0177 - mse: 0.0173
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0221 - mse: 0.0218
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0198 - mse: 0.0194
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0194 - mse: 0.0190
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0204 - mse: 0.0200
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0190 - mse: 0.0186
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0188 - mse: 0.0185
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0176 - mse: 0.0172
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0184 - mse: 0.0180
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0194 - mse: 0.0190
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0188 - mse: 0.0185
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0208 - mse: 0.0205
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0183 - mse: 0.0179
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0199 - mse: 0.0195
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0174 - mse: 0.0170
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0199 - mse: 0.0195
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0182 - mse: 0.0179
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0195 - mse: 0.0191
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0189 - mse: 0.0186
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0218 - mse: 0.0215
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 137ms/step - loss: 0.0220 - mse: 0.0217
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0185 - mse: 0.0181
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0180 - mse: 0.0177
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0202 - mse: 0.0199
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0192 - mse: 0.0188
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 146ms/step - loss: 0.0185 - mse: 0.0182
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 143ms/step - loss: 0.0186 - mse: 0.0183
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0191 - mse: 0.0188
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0198 - mse: 0.0195
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0201 - mse: 0.0198
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0221 - mse: 0.0218
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0182 - mse: 0.0178
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0191 - mse: 0.0188
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0196 - mse: 0.0192
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0190 - mse: 0.0187
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0184 - mse: 0.0180
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0193 - mse: 0.0190
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0195 - mse: 0.0191
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0191 - mse: 0.0188
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0205 - mse: 0.0202
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0194 - mse: 0.0190
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 139ms/step - loss: 0.0192 - mse: 0.0189
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0200 - mse: 0.0197
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0188 - mse: 0.0184
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0193 - mse: 0.0189
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0202 - mse: 0.0198
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0186 - mse: 0.0183
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0180 - mse: 0.0177
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0183 - mse: 0.0180
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0187 - mse: 0.0183
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0195 - mse: 0.0191
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0180 - mse: 0.0176
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0185 - mse: 0.0182
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0177 - mse: 0.0174
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0188 - mse: 0.0185
# Normal values:  (11307.931827778506, 0.1686838589252584, 0.019424812868237495, 0.0012678610888700464)
# Anomaly values:  (11297.58943866106, 18.778527418197093, 0.019133758881399707, 0.0008685010705310397)

# %%
#Now, input unknown images and sort as Good or Anomaly
# Also, display the images where the model predicts an anomaly

# Normal values:  (11307.173204610757, 0.00021034008735510042, 0.0010616554852364765, 0.0004691525145013336)
# Anomaly values:  (11281.388645922418, 18.430181872661812, 0.0022931333214435126, 0.00189302380217782)

density_threshold = 11306 #Set this value based on the above exercise
reconstruction_error_threshold = 0.03 # Set this value based on the above exercise

def check_anomaly(img_path):
    img  = Image.open(img_path)
    img = np.array(img.resize((128,128), Image.Resampling.LANCZOS))
    
    original_img = img.copy()
    
    img = img / 255.
    img = img[np.newaxis, :,:,:]
    
    encoded_img = encoder_model.predict([[img]]) 
    encoded_img = [np.reshape(img, (out_vector_shape)) for img in encoded_img] 
    
    density = kde.score_samples(encoded_img)[0] 

    reconstruction = model.predict([[img]])
    
    reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)[0]

    reconstruction_loss = np.abs(img - reconstruction)
    reconstruction_loss = np.mean(reconstruction_loss, axis=3)[0]
    
    return (density < density_threshold or reconstruction_error > reconstruction_error_threshold), original_img

# %% [markdown]
# ### Sanity Check and testing the model

# %%
#Load a couple of test images and verify whether they are reported as anomalies.
import glob
defective_file_paths = glob.glob('datasets/capsule/test/defective/**/*')
normal_file_paths = glob.glob('datasets/capsule/train/**/*')

tf.data.experimental.enable_debug_mode()

# %%
import PIL
from PIL import Image
if not hasattr(PIL.Image, 'Resampling'):  # Pillow<9.0
    PIL.Image.Resampling = PIL.Image
for _ in range(3):
    # test images
    random_img = np.random.randint(0, len(defective_file_paths))
    is_anomaly, original_img = check_anomaly(defective_file_paths[random_img])

    random_img2 = np.random.randint(0, len(normal_file_paths))
    is_anomaly2, original_img2 = check_anomaly(normal_file_paths[random_img])

    fig, ax = plt.subplots(1,2, figsize=(10,10))

    ax[0].imshow(original_img)
    ax[0].set_title("Anomaly" if is_anomaly else "Good")
    
    # add an overlay 
    

    ax[1].imshow(original_img2)
    ax[1].set_title("Anomaly" if is_anomaly2 else "Good")
# Out:
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 1s 510ms/step - loss: 0.0189 - mse: 0.0186
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 502ms/step
# 1/1 [==============================] - 0s 420ms/step - loss: 0.0187 - mse: 0.0183
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 0s 476ms/step - loss: 0.0186 - mse: 0.0183
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 465ms/step
# 1/1 [==============================] - 0s 470ms/step - loss: 0.0186 - mse: 0.0182
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 440ms/step - loss: 0.0199 - mse: 0.0196
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 474ms/step - loss: 0.0195 - mse: 0.0192

# %% [markdown]
# ### Calculating the AUROC for the model

# %%
def roc_auc_score(y_true, y_pred):
    return np.mean(np.array(y_true) == np.array(y_pred))

def calc_auroc():
    y_true = []
    y_pred = []
    for f in defective_file_paths:
        is_anomaly, _ = check_anomaly(f)
        y_true.append(1)
        y_pred.append(is_anomaly)
        
    for f in normal_file_paths:
        is_anomaly, _ = check_anomaly(f)
        y_true.append(0)
        y_pred.append(is_anomaly)
        
    return roc_auc_score(y_true, y_pred)

print("AUROC: ", calc_auroc())
# Out:
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 444ms/step
# 1/1 [==============================] - 1s 517ms/step - loss: 0.0201 - mse: 0.0198
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 409ms/step - loss: 0.0172 - mse: 0.0169
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 450ms/step - loss: 0.0181 - mse: 0.0178
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 454ms/step - loss: 0.0198 - mse: 0.0194
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 474ms/step - loss: 0.0191 - mse: 0.0187
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 472ms/step
# 1/1 [==============================] - 0s 413ms/step - loss: 0.0190 - mse: 0.0186
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 501ms/step
# 1/1 [==============================] - 0s 485ms/step - loss: 0.0182 - mse: 0.0178
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 488ms/step
# 1/1 [==============================] - 0s 411ms/step - loss: 0.0191 - mse: 0.0187
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 432ms/step - loss: 0.0202 - mse: 0.0198
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 0s 435ms/step - loss: 0.0186 - mse: 0.0183
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 435ms/step
# 1/1 [==============================] - 0s 460ms/step - loss: 0.0177 - mse: 0.0173
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 464ms/step
# 1/1 [==============================] - 0s 457ms/step - loss: 0.0179 - mse: 0.0176
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 449ms/step
# 1/1 [==============================] - 0s 433ms/step - loss: 0.0190 - mse: 0.0187
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 520ms/step
# 1/1 [==============================] - 0s 423ms/step - loss: 0.0195 - mse: 0.0192
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 488ms/step
# 1/1 [==============================] - 1s 522ms/step - loss: 0.0193 - mse: 0.0190
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 1s 502ms/step - loss: 0.0192 - mse: 0.0189
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 522ms/step
# 1/1 [==============================] - 0s 469ms/step - loss: 0.0192 - mse: 0.0189
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 1s 504ms/step
# 1/1 [==============================] - 1s 529ms/step - loss: 0.0196 - mse: 0.0192
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 503ms/step
# 1/1 [==============================] - 1s 537ms/step - loss: 0.0192 - mse: 0.0189
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 1s 515ms/step
# 1/1 [==============================] - 1s 521ms/step - loss: 0.0192 - mse: 0.0189
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 1s 509ms/step
# 1/1 [==============================] - 1s 535ms/step - loss: 0.0192 - mse: 0.0189
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 0s 439ms/step - loss: 0.0188 - mse: 0.0185
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 470ms/step
# 1/1 [==============================] - 1s 512ms/step - loss: 0.0201 - mse: 0.0197
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 506ms/step
# 1/1 [==============================] - 1s 535ms/step - loss: 0.0197 - mse: 0.0194
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 1s 503ms/step - loss: 0.0191 - mse: 0.0187
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 476ms/step
# 1/1 [==============================] - 1s 514ms/step - loss: 0.0193 - mse: 0.0190
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 503ms/step
# 1/1 [==============================] - 0s 475ms/step - loss: 0.0199 - mse: 0.0196
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 572ms/step - loss: 0.0202 - mse: 0.0198
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 517ms/step
# 1/1 [==============================] - 1s 559ms/step - loss: 0.0190 - mse: 0.0186
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 1s 549ms/step - loss: 0.0184 - mse: 0.0181
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 539ms/step
# 1/1 [==============================] - 1s 524ms/step - loss: 0.0186 - mse: 0.0183
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 459ms/step
# 1/1 [==============================] - 1s 528ms/step - loss: 0.0191 - mse: 0.0188
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 498ms/step
# 1/1 [==============================] - 1s 525ms/step - loss: 0.0190 - mse: 0.0187
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 523ms/step
# 1/1 [==============================] - 0s 484ms/step - loss: 0.0180 - mse: 0.0177
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 368ms/step
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0188 - mse: 0.0184
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0187 - mse: 0.0183
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 273ms/step
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0193 - mse: 0.0190
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 486ms/step
# 1/1 [==============================] - 1s 528ms/step - loss: 0.0194 - mse: 0.0190
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 509ms/step
# 1/1 [==============================] - 1s 540ms/step - loss: 0.0184 - mse: 0.0181
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 0s 490ms/step - loss: 0.0185 - mse: 0.0182
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 1s 502ms/step
# 1/1 [==============================] - 0s 472ms/step - loss: 0.0186 - mse: 0.0183
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 472ms/step
# 1/1 [==============================] - 1s 560ms/step - loss: 0.0188 - mse: 0.0185
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 492ms/step
# 1/1 [==============================] - 0s 453ms/step - loss: 0.0188 - mse: 0.0184
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 0s 490ms/step - loss: 0.0190 - mse: 0.0186
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 1s 501ms/step - loss: 0.0191 - mse: 0.0188
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 539ms/step
# 1/1 [==============================] - 1s 503ms/step - loss: 0.0213 - mse: 0.0209
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 1s 565ms/step - loss: 0.0198 - mse: 0.0195
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 1s 528ms/step - loss: 0.0195 - mse: 0.0191
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 456ms/step
# 1/1 [==============================] - 0s 487ms/step - loss: 0.0200 - mse: 0.0196
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 472ms/step
# 1/1 [==============================] - 1s 579ms/step - loss: 0.0192 - mse: 0.0188
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 1s 505ms/step
# 1/1 [==============================] - 0s 482ms/step - loss: 0.0192 - mse: 0.0188
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 1s 525ms/step
# 1/1 [==============================] - 0s 459ms/step - loss: 0.0192 - mse: 0.0188
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 480ms/step
# 1/1 [==============================] - 1s 525ms/step - loss: 0.0193 - mse: 0.0189
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 533ms/step - loss: 0.0189 - mse: 0.0186
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 472ms/step
# 1/1 [==============================] - 0s 469ms/step - loss: 0.0193 - mse: 0.0189
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 1s 534ms/step
# 1/1 [==============================] - 0s 487ms/step - loss: 0.0189 - mse: 0.0185
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 502ms/step
# 1/1 [==============================] - 1s 551ms/step - loss: 0.0190 - mse: 0.0186
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 1s 538ms/step - loss: 0.0187 - mse: 0.0184
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 504ms/step
# 1/1 [==============================] - 0s 451ms/step - loss: 0.0177 - mse: 0.0174
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 451ms/step
# 1/1 [==============================] - 0s 487ms/step - loss: 0.0188 - mse: 0.0185
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 519ms/step
# 1/1 [==============================] - 0s 424ms/step - loss: 0.0185 - mse: 0.0182
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 442ms/step
# 1/1 [==============================] - 1s 534ms/step - loss: 0.0183 - mse: 0.0180
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 509ms/step
# 1/1 [==============================] - 0s 425ms/step - loss: 0.0181 - mse: 0.0177
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 0s 456ms/step - loss: 0.0185 - mse: 0.0182
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 1s 509ms/step
# 1/1 [==============================] - 1s 533ms/step - loss: 0.0203 - mse: 0.0200
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 1s 518ms/step
# 1/1 [==============================] - 1s 567ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 565ms/step - loss: 0.0198 - mse: 0.0194
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 464ms/step
# 1/1 [==============================] - 1s 534ms/step - loss: 0.0195 - mse: 0.0192
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 537ms/step - loss: 0.0189 - mse: 0.0185
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 456ms/step
# 1/1 [==============================] - 1s 505ms/step - loss: 0.0183 - mse: 0.0180
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 1s 502ms/step
# 1/1 [==============================] - 1s 550ms/step - loss: 0.0191 - mse: 0.0187
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 449ms/step
# 1/1 [==============================] - 1s 510ms/step - loss: 0.0191 - mse: 0.0187
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 488ms/step
# 1/1 [==============================] - 1s 518ms/step - loss: 0.0187 - mse: 0.0183
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 527ms/step
# 1/1 [==============================] - 1s 519ms/step - loss: 0.0188 - mse: 0.0185
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 519ms/step - loss: 0.0191 - mse: 0.0188
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 1s 535ms/step
# 1/1 [==============================] - 1s 506ms/step - loss: 0.0179 - mse: 0.0175
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 479ms/step
# 1/1 [==============================] - 0s 493ms/step - loss: 0.0200 - mse: 0.0197
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 488ms/step
# 1/1 [==============================] - 0s 458ms/step - loss: 0.0195 - mse: 0.0192
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 489ms/step
# 1/1 [==============================] - 1s 505ms/step - loss: 0.0189 - mse: 0.0186
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 1s 569ms/step - loss: 0.0192 - mse: 0.0189
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 1s 507ms/step - loss: 0.0186 - mse: 0.0183
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 476ms/step
# 1/1 [==============================] - 1s 519ms/step - loss: 0.0184 - mse: 0.0181
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 1s 524ms/step - loss: 0.0189 - mse: 0.0185
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 1s 550ms/step - loss: 0.0189 - mse: 0.0186
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 1s 519ms/step
# 1/1 [==============================] - 1s 520ms/step - loss: 0.0176 - mse: 0.0173
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 1s 538ms/step
# 1/1 [==============================] - 1s 505ms/step - loss: 0.0188 - mse: 0.0184
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 491ms/step
# 1/1 [==============================] - 1s 549ms/step - loss: 0.0187 - mse: 0.0184
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 558ms/step - loss: 0.0183 - mse: 0.0179
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 0s 487ms/step - loss: 0.0179 - mse: 0.0176
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 445ms/step
# 1/1 [==============================] - 1s 539ms/step - loss: 0.0208 - mse: 0.0204
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 1s 582ms/step - loss: 0.0223 - mse: 0.0220
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 1s 519ms/step
# 1/1 [==============================] - 1s 550ms/step - loss: 0.0186 - mse: 0.0182
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 1s 535ms/step
# 1/1 [==============================] - 1s 536ms/step - loss: 0.0190 - mse: 0.0186
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 486ms/step
# 1/1 [==============================] - 1s 524ms/step - loss: 0.0180 - mse: 0.0176
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 535ms/step - loss: 0.0192 - mse: 0.0189
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 423ms/step
# 1/1 [==============================] - 1s 566ms/step - loss: 0.0198 - mse: 0.0195
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 518ms/step
# 1/1 [==============================] - 1s 549ms/step - loss: 0.0218 - mse: 0.0215
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 0s 477ms/step - loss: 0.0189 - mse: 0.0186
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 1s 504ms/step
# 1/1 [==============================] - 1s 581ms/step - loss: 0.0157 - mse: 0.0154
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 509ms/step - loss: 0.0185 - mse: 0.0182
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 519ms/step
# 1/1 [==============================] - 1s 564ms/step - loss: 0.0217 - mse: 0.0214
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 523ms/step
# 1/1 [==============================] - 0s 444ms/step - loss: 0.0186 - mse: 0.0182
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 504ms/step - loss: 0.0174 - mse: 0.0170
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 540ms/step
# 1/1 [==============================] - 1s 539ms/step - loss: 0.0219 - mse: 0.0215
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 504ms/step
# 1/1 [==============================] - 1s 526ms/step - loss: 0.0166 - mse: 0.0163
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 0s 489ms/step - loss: 0.0206 - mse: 0.0202
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 1s 504ms/step - loss: 0.0173 - mse: 0.0170
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 508ms/step
# 1/1 [==============================] - 1s 571ms/step - loss: 0.0176 - mse: 0.0173
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 541ms/step - loss: 0.0192 - mse: 0.0189
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 591ms/step - loss: 0.0198 - mse: 0.0194
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 490ms/step
# 1/1 [==============================] - 0s 500ms/step - loss: 0.0218 - mse: 0.0215
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 543ms/step
# 1/1 [==============================] - 1s 552ms/step - loss: 0.0190 - mse: 0.0186
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 546ms/step - loss: 0.0204 - mse: 0.0201
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 554ms/step
# 1/1 [==============================] - 1s 518ms/step - loss: 0.0201 - mse: 0.0198
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 1s 613ms/step - loss: 0.0198 - mse: 0.0195
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 1s 569ms/step - loss: 0.0195 - mse: 0.0192
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 491ms/step
# 1/1 [==============================] - 1s 596ms/step - loss: 0.0195 - mse: 0.0191
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 450ms/step
# 1/1 [==============================] - 1s 516ms/step - loss: 0.0192 - mse: 0.0189
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 490ms/step
# 1/1 [==============================] - 1s 535ms/step - loss: 0.0199 - mse: 0.0195
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 542ms/step - loss: 0.0193 - mse: 0.0190
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 534ms/step - loss: 0.0197 - mse: 0.0194
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 1s 542ms/step
# 1/1 [==============================] - 1s 543ms/step - loss: 0.0224 - mse: 0.0221
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 526ms/step - loss: 0.0197 - mse: 0.0193
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 575ms/step - loss: 0.0199 - mse: 0.0196
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 519ms/step - loss: 0.0188 - mse: 0.0185
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 539ms/step - loss: 0.0193 - mse: 0.0189
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 489ms/step
# 1/1 [==============================] - 0s 485ms/step - loss: 0.0193 - mse: 0.0189
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0187 - mse: 0.0184
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 1s 518ms/step
# 1/1 [==============================] - 0s 440ms/step - loss: 0.0221 - mse: 0.0218
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 457ms/step
# 1/1 [==============================] - 1s 538ms/step - loss: 0.0182 - mse: 0.0178
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 423ms/step
# 1/1 [==============================] - 1s 508ms/step - loss: 0.0197 - mse: 0.0193
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 1s 506ms/step
# 1/1 [==============================] - 1s 558ms/step - loss: 0.0206 - mse: 0.0202
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 1s 542ms/step - loss: 0.0193 - mse: 0.0189
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 0s 415ms/step - loss: 0.0194 - mse: 0.0190
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 482ms/step
# 1/1 [==============================] - 1s 554ms/step - loss: 0.0191 - mse: 0.0187
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 565ms/step - loss: 0.0198 - mse: 0.0195
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 517ms/step
# 1/1 [==============================] - 1s 582ms/step - loss: 0.0195 - mse: 0.0192
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 519ms/step - loss: 0.0198 - mse: 0.0194
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 1s 537ms/step
# 1/1 [==============================] - 1s 585ms/step - loss: 0.0193 - mse: 0.0189
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 543ms/step
# 1/1 [==============================] - 1s 597ms/step - loss: 0.0227 - mse: 0.0224
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 582ms/step - loss: 0.0197 - mse: 0.0194
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 597ms/step - loss: 0.0195 - mse: 0.0192
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 618ms/step - loss: 0.0194 - mse: 0.0191
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 1s 594ms/step - loss: 0.0200 - mse: 0.0196
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 561ms/step - loss: 0.0199 - mse: 0.0195
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 559ms/step - loss: 0.0197 - mse: 0.0193
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 1s 539ms/step
# 1/1 [==============================] - 1s 528ms/step - loss: 0.0194 - mse: 0.0190
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 582ms/step - loss: 0.0193 - mse: 0.0189
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 523ms/step
# 1/1 [==============================] - 1s 539ms/step - loss: 0.0194 - mse: 0.0190
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 1s 556ms/step - loss: 0.0186 - mse: 0.0183
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 464ms/step
# 1/1 [==============================] - 0s 469ms/step - loss: 0.0229 - mse: 0.0225
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 1s 544ms/step - loss: 0.0188 - mse: 0.0184
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 472ms/step
# 1/1 [==============================] - 1s 586ms/step - loss: 0.0187 - mse: 0.0184
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 591ms/step - loss: 0.0183 - mse: 0.0180
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 534ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 540ms/step - loss: 0.0190 - mse: 0.0187
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 1s 597ms/step - loss: 0.0200 - mse: 0.0196
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 514ms/step - loss: 0.0193 - mse: 0.0189
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 522ms/step
# 1/1 [==============================] - 1s 608ms/step - loss: 0.0190 - mse: 0.0187
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 1s 522ms/step
# 1/1 [==============================] - 0s 491ms/step - loss: 0.0201 - mse: 0.0197
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 524ms/step
# 1/1 [==============================] - 1s 504ms/step - loss: 0.0221 - mse: 0.0218
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 648ms/step - loss: 0.0198 - mse: 0.0193
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 1s 504ms/step
# 1/1 [==============================] - 1s 622ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 565ms/step - loss: 0.0186 - mse: 0.0183
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 1s 627ms/step
# 1/1 [==============================] - 1s 592ms/step - loss: 0.0189 - mse: 0.0186
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 564ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 517ms/step
# 1/1 [==============================] - 1s 604ms/step - loss: 0.0191 - mse: 0.0188
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 572ms/step - loss: 0.0187 - mse: 0.0184
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 527ms/step
# 1/1 [==============================] - 1s 570ms/step - loss: 0.0191 - mse: 0.0188
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 502ms/step
# 1/1 [==============================] - 1s 597ms/step - loss: 0.0192 - mse: 0.0189
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 612ms/step - loss: 0.0193 - mse: 0.0190
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 497ms/step
# 1/1 [==============================] - 1s 526ms/step - loss: 0.0186 - mse: 0.0182
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 537ms/step - loss: 0.0187 - mse: 0.0184
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 512ms/step
# 1/1 [==============================] - 1s 552ms/step - loss: 0.0188 - mse: 0.0184
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 551ms/step
# 1/1 [==============================] - 1s 549ms/step - loss: 0.0199 - mse: 0.0196
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 1s 534ms/step
# 1/1 [==============================] - 1s 594ms/step - loss: 0.0194 - mse: 0.0191
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 615ms/step - loss: 0.0181 - mse: 0.0177
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 566ms/step - loss: 0.0183 - mse: 0.0179
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 600ms/step - loss: 0.0188 - mse: 0.0185
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 503ms/step
# 1/1 [==============================] - 1s 582ms/step - loss: 0.0195 - mse: 0.0192
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 617ms/step - loss: 0.0226 - mse: 0.0223
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 1s 502ms/step
# 1/1 [==============================] - 1s 581ms/step - loss: 0.0188 - mse: 0.0184
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 550ms/step - loss: 0.0185 - mse: 0.0181
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 597ms/step - loss: 0.0183 - mse: 0.0179
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 589ms/step - loss: 0.0187 - mse: 0.0184
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 565ms/step - loss: 0.0183 - mse: 0.0180
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 519ms/step
# 1/1 [==============================] - 1s 643ms/step - loss: 0.0181 - mse: 0.0178
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0186 - mse: 0.0183
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 506ms/step - loss: 0.0225 - mse: 0.0223
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 553ms/step - loss: 0.0192 - mse: 0.0188
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 480ms/step
# 1/1 [==============================] - 1s 579ms/step - loss: 0.0181 - mse: 0.0178
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 545ms/step
# 1/1 [==============================] - 1s 596ms/step - loss: 0.0205 - mse: 0.0201
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0190 - mse: 0.0187
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 583ms/step - loss: 0.0209 - mse: 0.0205
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 616ms/step - loss: 0.0200 - mse: 0.0196
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 534ms/step - loss: 0.0182 - mse: 0.0178
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0189 - mse: 0.0186
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 548ms/step - loss: 0.0184 - mse: 0.0180
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 565ms/step - loss: 0.0228 - mse: 0.0225
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 505ms/step
# 1/1 [==============================] - 1s 582ms/step - loss: 0.0176 - mse: 0.0172
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 501ms/step - loss: 0.0185 - mse: 0.0182
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 541ms/step
# 1/1 [==============================] - 1s 612ms/step - loss: 0.0180 - mse: 0.0176
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 1s 619ms/step
# 1/1 [==============================] - 1s 630ms/step - loss: 0.0184 - mse: 0.0180
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 525ms/step
# 1/1 [==============================] - 1s 627ms/step - loss: 0.0184 - mse: 0.0180
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 621ms/step
# 1/1 [==============================] - 1s 613ms/step - loss: 0.0178 - mse: 0.0174
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 620ms/step - loss: 0.0183 - mse: 0.0179
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 553ms/step - loss: 0.0185 - mse: 0.0181
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 612ms/step - loss: 0.0182 - mse: 0.0178
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 618ms/step
# 1/1 [==============================] - 1s 582ms/step - loss: 0.0216 - mse: 0.0213
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 612ms/step - loss: 0.0190 - mse: 0.0187
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 0s 441ms/step - loss: 0.0184 - mse: 0.0181
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 1s 551ms/step
# 1/1 [==============================] - 1s 650ms/step - loss: 0.0188 - mse: 0.0185
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 584ms/step - loss: 0.0190 - mse: 0.0187
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 615ms/step - loss: 0.0177 - mse: 0.0173
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 508ms/step
# 1/1 [==============================] - 1s 613ms/step - loss: 0.0186 - mse: 0.0182
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 685ms/step - loss: 0.0203 - mse: 0.0199
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 540ms/step
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0181 - mse: 0.0178
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 521ms/step - loss: 0.0187 - mse: 0.0184
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 690ms/step - loss: 0.0184 - mse: 0.0181
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 598ms/step - loss: 0.0188 - mse: 0.0184
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 645ms/step
# 1/1 [==============================] - 1s 597ms/step - loss: 0.0179 - mse: 0.0176
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 628ms/step
# 1/1 [==============================] - 1s 519ms/step - loss: 0.0177 - mse: 0.0174
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 661ms/step
# 1/1 [==============================] - 1s 564ms/step - loss: 0.0170 - mse: 0.0166
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 1s 618ms/step
# 1/1 [==============================] - 1s 661ms/step - loss: 0.0180 - mse: 0.0177
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 645ms/step
# 1/1 [==============================] - 1s 603ms/step - loss: 0.0186 - mse: 0.0183
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 1s 534ms/step
# 1/1 [==============================] - 1s 607ms/step - loss: 0.0189 - mse: 0.0185
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 517ms/step - loss: 0.0191 - mse: 0.0187
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 676ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 1s 632ms/step - loss: 0.0199 - mse: 0.0196
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 551ms/step
# 1/1 [==============================] - 1s 566ms/step - loss: 0.0199 - mse: 0.0195
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 581ms/step - loss: 0.0201 - mse: 0.0198
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 612ms/step - loss: 0.0204 - mse: 0.0200
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 618ms/step - loss: 0.0177 - mse: 0.0174
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 613ms/step - loss: 0.0185 - mse: 0.0182
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 597ms/step - loss: 0.0182 - mse: 0.0179
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 589ms/step - loss: 0.0175 - mse: 0.0172
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 627ms/step
# 1/1 [==============================] - 1s 621ms/step - loss: 0.0186 - mse: 0.0183
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 596ms/step - loss: 0.0184 - mse: 0.0180
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 1s 639ms/step
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0200 - mse: 0.0197
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0183 - mse: 0.0179
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 0s 457ms/step - loss: 0.0182 - mse: 0.0178
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 361ms/step - loss: 0.0176 - mse: 0.0172
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 338ms/step - loss: 0.0191 - mse: 0.0188
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 366ms/step - loss: 0.0197 - mse: 0.0194
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 336ms/step
# 1/1 [==============================] - 0s 350ms/step - loss: 0.0192 - mse: 0.0189
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 1s 519ms/step
# 1/1 [==============================] - 1s 526ms/step - loss: 0.0190 - mse: 0.0186
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 682ms/step - loss: 0.0183 - mse: 0.0180
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 723ms/step - loss: 0.0199 - mse: 0.0195
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 647ms/step - loss: 0.0192 - mse: 0.0188
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 631ms/step
# 1/1 [==============================] - 1s 532ms/step - loss: 0.0195 - mse: 0.0191
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 1s 588ms/step - loss: 0.0201 - mse: 0.0198
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 1s 630ms/step
# 1/1 [==============================] - 1s 581ms/step - loss: 0.0217 - mse: 0.0213
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 667ms/step - loss: 0.0199 - mse: 0.0196
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 534ms/step
# 1/1 [==============================] - 1s 619ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 707ms/step - loss: 0.0185 - mse: 0.0182
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 1s 545ms/step - loss: 0.0199 - mse: 0.0195
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 645ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 636ms/step
# 1/1 [==============================] - 1s 598ms/step - loss: 0.0188 - mse: 0.0185
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 612ms/step - loss: 0.0191 - mse: 0.0188
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 620ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 707ms/step
# 1/1 [==============================] - 1s 628ms/step - loss: 0.0198 - mse: 0.0194
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 592ms/step - loss: 0.0211 - mse: 0.0208
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 1s 535ms/step
# 1/1 [==============================] - 1s 576ms/step - loss: 0.0192 - mse: 0.0189
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 665ms/step - loss: 0.0189 - mse: 0.0186
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 661ms/step
# 1/1 [==============================] - 1s 722ms/step - loss: 0.0198 - mse: 0.0195
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 659ms/step - loss: 0.0195 - mse: 0.0192
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 1s 636ms/step
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0210 - mse: 0.0207
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 573ms/step - loss: 0.0197 - mse: 0.0194
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 1s 644ms/step
# 1/1 [==============================] - 1s 690ms/step - loss: 0.0200 - mse: 0.0197
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 708ms/step - loss: 0.0199 - mse: 0.0195
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 574ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0189 - mse: 0.0186
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 651ms/step
# 1/1 [==============================] - 1s 663ms/step - loss: 0.0219 - mse: 0.0216
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 612ms/step
# 1/1 [==============================] - 1s 596ms/step - loss: 0.0198 - mse: 0.0195
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 691ms/step - loss: 0.0198 - mse: 0.0195
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 661ms/step - loss: 0.0204 - mse: 0.0200
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 691ms/step
# 1/1 [==============================] - 1s 615ms/step - loss: 0.0190 - mse: 0.0187
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 675ms/step
# 1/1 [==============================] - 1s 638ms/step - loss: 0.0199 - mse: 0.0196
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 1s 612ms/step
# 1/1 [==============================] - 1s 662ms/step - loss: 0.0207 - mse: 0.0204
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0223 - mse: 0.0220
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 1s 618ms/step
# 1/1 [==============================] - 1s 613ms/step - loss: 0.0207 - mse: 0.0203
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 681ms/step - loss: 0.0217 - mse: 0.0213
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 719ms/step
# 1/1 [==============================] - 1s 529ms/step - loss: 0.0198 - mse: 0.0194
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 1s 676ms/step - loss: 0.0207 - mse: 0.0204
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 626ms/step - loss: 0.0194 - mse: 0.0190
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 629ms/step - loss: 0.0202 - mse: 0.0199
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 1s 502ms/step
# 1/1 [==============================] - 1s 566ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 593ms/step - loss: 0.0207 - mse: 0.0203
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 512ms/step - loss: 0.0198 - mse: 0.0195
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 658ms/step - loss: 0.0203 - mse: 0.0200
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 656ms/step - loss: 0.0203 - mse: 0.0200
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 612ms/step
# 1/1 [==============================] - 1s 651ms/step - loss: 0.0194 - mse: 0.0191
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 723ms/step - loss: 0.0190 - mse: 0.0187
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 503ms/step
# 1/1 [==============================] - 1s 675ms/step - loss: 0.0189 - mse: 0.0185
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 1s 634ms/step
# 1/1 [==============================] - 1s 690ms/step - loss: 0.0202 - mse: 0.0199
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 1s 675ms/step
# 1/1 [==============================] - 1s 605ms/step - loss: 0.0197 - mse: 0.0194
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 628ms/step
# 1/1 [==============================] - 1s 752ms/step - loss: 0.0194 - mse: 0.0191
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 530ms/step
# 1/1 [==============================] - 1s 644ms/step - loss: 0.0195 - mse: 0.0191
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 643ms/step
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0199 - mse: 0.0195
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 673ms/step
# 1/1 [==============================] - 1s 656ms/step - loss: 0.0218 - mse: 0.0215
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 1s 707ms/step
# 1/1 [==============================] - 1s 550ms/step - loss: 0.0202 - mse: 0.0199
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 538ms/step - loss: 0.0202 - mse: 0.0199
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 678ms/step - loss: 0.0195 - mse: 0.0192
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 654ms/step
# 1/1 [==============================] - 1s 570ms/step - loss: 0.0198 - mse: 0.0194
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 678ms/step
# 1/1 [==============================] - 1s 557ms/step - loss: 0.0202 - mse: 0.0198
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 643ms/step
# 1/1 [==============================] - 1s 620ms/step - loss: 0.0204 - mse: 0.0201
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 1s 519ms/step
# 1/1 [==============================] - 1s 666ms/step - loss: 0.0200 - mse: 0.0196
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 612ms/step
# 1/1 [==============================] - 1s 660ms/step - loss: 0.0198 - mse: 0.0194
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 666ms/step
# 1/1 [==============================] - 1s 660ms/step - loss: 0.0197 - mse: 0.0194
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 662ms/step
# 1/1 [==============================] - 1s 636ms/step - loss: 0.0229 - mse: 0.0225
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 659ms/step
# 1/1 [==============================] - 1s 702ms/step - loss: 0.0195 - mse: 0.0191
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 676ms/step - loss: 0.0186 - mse: 0.0183
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 1s 674ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 613ms/step - loss: 0.0193 - mse: 0.0189
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 661ms/step - loss: 0.0190 - mse: 0.0187
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 628ms/step
# 1/1 [==============================] - 1s 653ms/step - loss: 0.0198 - mse: 0.0194
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 644ms/step
# 1/1 [==============================] - 1s 674ms/step - loss: 0.0193 - mse: 0.0190
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 691ms/step
# 1/1 [==============================] - 1s 653ms/step - loss: 0.0203 - mse: 0.0199
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 1s 753ms/step
# 1/1 [==============================] - 1s 672ms/step - loss: 0.0200 - mse: 0.0196
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 519ms/step
# 1/1 [==============================] - 1s 522ms/step - loss: 0.0213 - mse: 0.0210
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 626ms/step - loss: 0.0201 - mse: 0.0198
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0191 - mse: 0.0187
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 683ms/step - loss: 0.0191 - mse: 0.0188
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 613ms/step - loss: 0.0196 - mse: 0.0193
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 692ms/step - loss: 0.0196 - mse: 0.0192
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 536ms/step
# 1/1 [==============================] - 1s 529ms/step - loss: 0.0193 - mse: 0.0189
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 1s 611ms/step
# 1/1 [==============================] - 1s 691ms/step - loss: 0.0202 - mse: 0.0198
# AUROC:  0.9573170731707317

# %% [markdown]
# ### Let's see if the model is able to localize the anomalies

# %%
import cv2

reconstruction_error_threshold = 0.001

def check_anomaly_localization(img_path):
    img  = Image.open(img_path)
    img = np.array(img.resize((128,128), Image.Resampling.LANCZOS))
    
    original_img = img.copy()
    
    img = img / 255.
    img = img[np.newaxis, :,:,:]
    
    encoded_img = encoder_model.predict([[img]]) 
    encoded_img = [np.reshape(img, (out_vector_shape)) for img in encoded_img] 
    
    density = kde.score_samples(encoded_img)[0] 

    reconstruction = model.predict([[img]])
    
    
    
    reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)
        
    reconstruction_error = reconstruction_error[1]

    reconstruction_loss = np.abs(img - reconstruction)
    reconstruction_loss = np.mean(reconstruction_loss, axis=3)[0]
    
    # add a mask of the reconstruction loss as a heatmap
    mask = reconstruction_loss > 0.1
    overlay = original_img.copy()
    overlay[mask] = [255, 0, 0]
    
    # join close regions of the mask, and remove sparse pixels
    new_overlay = np.zeros_like(overlay)
    new_overlay = cv2.morphologyEx(overlay, cv2.MORPH_CLOSE, np.ones((5,5), np.uint8))
    
    
    # remove small regions of the mask that are not part of the anomaly
    contours, _ = cv2.findContours(new_overlay[:,:,1], cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    
    for cnt in contours:
        if cv2.contourArea(cnt) < 75:
            cv2.drawContours(new_overlay, [cnt], -1, (0,0,0), -1)
            
    return (density < density_threshold or reconstruction_error > reconstruction_error_threshold), original_img, new_overlay

# %%
file_paths = defective_file_paths

for _ in range(10):
    # test images
    random_img = np.random.randint(0, len(file_paths))
    
    random_img = file_paths[random_img]
    
    image_name = random_img.split('/')[-1]
    image_name = image_name.split("\\")[-2:]
    image_name = '/'.join(image_name) 
    
    # remove the .png extension
    image_name = image_name[:-4]
    
    # add _mask.png
    image_name += '_mask.png'
    
    original_path = 'datasets/capsule'
    
    gt = Image.open(f'{original_path}/ground_truth/{image_name}').convert('RGBA').resize((128,128), Image.Resampling.LANCZOS)
    

    is_anomaly, original_img, mask = check_anomaly_localization(random_img)

    fig, ax = plt.subplots(1,3, figsize=(10,4))
    
    fig.suptitle("Anomaly" if is_anomaly else "Good")
    
    ax[0].imshow(original_img)
    ax[0].set_title("Original")
    
    ax[1].imshow(original_img)

    
    ax[1].imshow(mask, alpha=1)
    ax[1].set_title("Localization")
    
    ax[2].imshow(original_img)
    
    gt = np.array(gt)
    
    a = np.zeros_like(gt)
    a[gt[:,:,0] > 0] = [0, 0,255, 255]
    
    ax[2].imshow(a, alpha=1)
    ax[2].imshow(mask, alpha=0.5)
    ax[2].set_title("Ground Truth")
    
    
    plt.show()
# Out:
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 652ms/step - loss: 0.0202 - mse: 0.0199
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 583ms/step - loss: 0.0184 - mse: 0.0180
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 1s 637ms/step
# 1/1 [==============================] - 1s 584ms/step - loss: 0.0181 - mse: 0.0178
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 1s 674ms/step
# 1/1 [==============================] - 1s 587ms/step - loss: 0.0196 - mse: 0.0192
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 649ms/step - loss: 0.0190 - mse: 0.0186
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 1s 525ms/step
# 1/1 [==============================] - 1s 640ms/step - loss: 0.0182 - mse: 0.0178
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 1s 627ms/step
# 1/1 [==============================] - 1s 631ms/step - loss: 0.0198 - mse: 0.0195
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 535ms/step
# 1/1 [==============================] - 1s 613ms/step - loss: 0.0209 - mse: 0.0205
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 1s 628ms/step
# 1/1 [==============================] - 1s 627ms/step - loss: 0.0198 - mse: 0.0195
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 1s 628ms/step
# 1/1 [==============================] - 1s 581ms/step - loss: 0.0201 - mse: 0.0198
