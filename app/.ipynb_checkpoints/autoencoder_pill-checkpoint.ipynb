# %%
#!pip install -r "C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt" --user
# Out:
# Requirement already satisfied: absl-py==1.4.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: asttokens==2.2.1 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: backcall==0.2.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: cachetools==5.3.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 5)) (5.3.0)
# Requirement already satisfied: certifi==2022.12.7 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 6)) (2022.12.7)
# Requirement already satisfied: charset-normalizer==3.0.1 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 7)) (3.0.1)
# Requirement already satisfied: colorama==0.4.6 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: comm==0.1.2 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: contourpy==1.0.7 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 10)) (1.0.7)
# Requirement already satisfied: cycler==0.11.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 11)) (0.11.0)
# Requirement already satisfied: debugpy==1.6.6 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 12)) (1.6.6)
# Requirement already satisfied: decorator==5.1.1 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 13)) (5.1.1)
# Requirement already satisfied: executing==1.2.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 14)) (1.2.0)
# Requirement already satisfied: flatbuffers==23.1.21 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 15)) (23.1.21)
# Requirement already satisfied: fonttools==4.39.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 16)) (4.39.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 17)) (0.4.0)
# Requirement already satisfied: google-auth==2.16.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 18)) (2.16.0)
# Requirement already satisfied: google-auth-oauthlib==0.4.6 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 19)) (0.4.6)
# Requirement already satisfied: google-pasta==0.2.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 20)) (0.2.0)
# Requirement already satisfied: grpcio==1.51.1 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 21)) (1.51.1)
# Requirement already satisfied: h5py==3.8.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 22)) (3.8.0)
# Requirement already satisfied: idna==3.4 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 23)) (3.4)
# Requirement already satisfied: ipykernel==6.21.3 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 24)) (6.21.3)
# Requirement already satisfied: ipython==8.11.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 25)) (8.11.0)
# Requirement already satisfied: jedi==0.18.2 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 26)) (0.18.2)
# Requirement already satisfied: joblib==1.2.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 27)) (1.2.0)
# Requirement already satisfied: jupyter_client==8.0.3 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 28)) (8.0.3)
# Requirement already satisfied: jupyter_core==5.2.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 29)) (5.2.0)
# Requirement already satisfied: keras==2.11.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 30)) (2.11.0)
# Requirement already satisfied: kiwisolver==1.4.4 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 31)) (1.4.4)
# Requirement already satisfied: libclang==15.0.6.1 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 32)) (15.0.6.1)
# Requirement already satisfied: Markdown==3.4.1 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 33)) (3.4.1)
# Requirement already satisfied: MarkupSafe==2.1.2 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 34)) (2.1.2)
# Requirement already satisfied: matplotlib==3.7.1 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 35)) (3.7.1)
# Requirement already satisfied: matplotlib-inline==0.1.6 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 36)) (0.1.6)
# Requirement already satisfied: nest-asyncio==1.5.6 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 37)) (1.5.6)
# Requirement already satisfied: numpy==1.24.2 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 38)) (1.24.2)
# Requirement already satisfied: oauthlib==3.2.2 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 39)) (3.2.2)
# Requirement already satisfied: opencv-python==4.7.0.72 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 40)) (4.7.0.72)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 41)) (3.3.0)
# Requirement already satisfied: packaging==23.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 42)) (23.0)
# Requirement already satisfied: parso==0.8.3 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 43)) (0.8.3)
# Requirement already satisfied: pickleshare==0.7.5 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 44)) (0.7.5)
# Requirement already satisfied: Pillow==9.4.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 45)) (9.4.0)
# Requirement already satisfied: platformdirs==3.1.1 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 46)) (3.1.1)
# Requirement already satisfied: prompt-toolkit==3.0.38 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 47)) (3.0.38)
# Requirement already satisfied: protobuf==3.19.6 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 48)) (3.19.6)
# Requirement already satisfied: psutil==5.9.4 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 49)) (5.9.4)
# Requirement already satisfied: pure-eval==0.2.2 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 50)) (0.2.2)
# Requirement already satisfied: pyasn1==0.4.8 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 51)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 52)) (0.2.8)
# Requirement already satisfied: Pygments==2.14.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 53)) (2.14.0)
# Requirement already satisfied: pyparsing==3.0.9 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 54)) (3.0.9)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 55)) (2.8.2)
# Requirement already satisfied: pywin32==305 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 56)) (305)
# Requirement already satisfied: pyzmq==25.0.1 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 57)) (25.0.1)
# Requirement already satisfied: requests==2.28.2 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 58)) (2.28.2)
# Requirement already satisfied: requests-oauthlib==1.3.1 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 59)) (1.3.1)
# Requirement already satisfied: rsa==4.9 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 60)) (4.9)
# Requirement already satisfied: scikit-learn==1.2.2 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 61)) (1.2.2)
# Requirement already satisfied: scipy==1.10.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 62)) (1.10.0)
# Requirement already satisfied: six==1.16.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 63)) (1.16.0)
# Requirement already satisfied: stack-data==0.6.2 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 64)) (0.6.2)
# Requirement already satisfied: tabulate==0.9.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 65)) (0.9.0)
# Requirement already satisfied: tensorboard==2.11.2 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 66)) (2.11.2)
# Requirement already satisfied: tensorboard-data-server==0.6.1 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 67)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.1 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 68)) (1.8.1)
# Requirement already satisfied: tensorflow==2.11.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 69)) (2.11.0)
# Requirement already satisfied: tensorflow-estimator==2.11.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 70)) (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 71)) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.30.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 72)) (0.30.0)
# Requirement already satisfied: termcolor==2.2.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 73)) (2.2.0)
# Requirement already satisfied: threadpoolctl==3.1.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 74)) (3.1.0)
# Requirement already satisfied: tifffile==2023.2.3 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 75)) (2023.2.3)
# Requirement already satisfied: tornado==6.2 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 76)) (6.2)
# Requirement already satisfied: tqdm==4.64.1 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 77)) (4.64.1)
# Requirement already satisfied: traitlets==5.9.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 78)) (5.9.0)
# Requirement already satisfied: typing_extensions==4.5.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 79)) (4.5.0)
# Requirement already satisfied: urllib3==1.26.14 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 80)) (1.26.14)
# Requirement already satisfied: wcwidth==0.2.6 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 81)) (0.2.6)
# Requirement already satisfied: Werkzeug==2.2.3 in c:\users\madhu\appdata\roaming\python\python310\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 82)) (2.2.3)
# Requirement already satisfied: wrapt==1.14.1 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from -r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 83)) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from astunparse==1.6.3->-r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 3)) (0.37.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages (from tensorboard==2.11.2->-r C:\Users\madhu\cis590kproject\CIS-590K-490I-sspcab\requirements.txt (line 66)) (58.1.0)
# WARNING: Ignoring invalid distribution -illow (c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#!pip install Pillow==9.0.0
# Out:
# Collecting Pillow==9.0.0
#   Using cached Pillow-9.0.0-cp310-cp310-win_amd64.whl (3.2 MB)
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# Successfully installed Pillow-9.0.0
# WARNING: Ignoring invalid distribution -illow (c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\madhu\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
import tensorflow as tf

tf.config.run_functions_eagerly(True)

from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random

print(tf.__version__)
# Out:
# 2.11.0

# %%
class SSPCAB(tf.keras.layers.Layer):
    def __init__(self, kernel_dim, dilation, filters, reduction_ratio=8, name=None, **kwargs):
        super(SSPCAB, self).__init__(name=name, **kwargs)
        
        self.kernel_dim = kernel_dim
        self.dilation = dilation
        self.filters = filters
        self.reduction_ratio = reduction_ratio
        
        self.pad = kernel_dim + dilation
        self.border_input = kernel_dim + 2*dilation + 1
        
        self.sspcab_1 = tf.keras.layers.Conv2D(
            filters=filters, kernel_size=kernel_dim, activation=tf.nn.relu, name=f'{name}_1')
        
        self.sspcab_3 = tf.keras.layers.Conv2D(
            filters=filters, kernel_size=kernel_dim, activation=tf.nn.relu, name=f'{name}_3')
        
        self.sspcab_7 = tf.keras.layers.Conv2D(
            filters=filters, kernel_size=kernel_dim, activation=tf.nn.relu, name=f'{name}_7')
        
        self.sspcab_9 = tf.keras.layers.Conv2D(
            filters=filters, kernel_size=kernel_dim, activation=tf.nn.relu, name=f'{name}_9')
    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'kernel_dim': self.kernel_dim,
            'dilation': self.dilation,
            'filters': self.filters,
            'reduction_ratio': self.reduction_ratio,
            'name': self.name
        })
        return config
        
    def se_block(self, input_x, in_channels, ratio):
        squeeze = tf.reduce_mean(input_x, axis=[1, 2])
        
        excitation = tf.keras.layers.Dense(use_bias=True, units=in_channels / ratio, name='sspcab_se_1')(squeeze)
        excitation = tf.nn.relu(excitation)
        excitation = tf.keras.layers.Dense(use_bias=True, units=in_channels, name='sspcab_se_2')(excitation)
        excitation = tf.nn.sigmoid(excitation)

        excitation = tf.reshape(excitation, [-1, 1, 1, in_channels])
        scale = input_x * excitation
        
        return scale
        
    def call(self, inputs, *args, **kwargs):
        sspcab_input = tf.pad(inputs, tf.constant([[0, 0], [self.pad, self.pad], [self.pad, self.pad], [0, 0]]), "REFLECT")
        
        out_1 = self.sspcab_1(sspcab_input[:, :-self.border_input, :-self.border_input, :])
        out_3 = self.sspcab_3(sspcab_input[:, self.border_input:, :-self.border_input, :])
        out_7 = self.sspcab_7(sspcab_input[:, :-self.border_input, self.border_input:, :])
        out_9 = self.sspcab_9(sspcab_input[:, self.border_input:, self.border_input:, :])
        
        sspcab_out = out_1 + out_3 + out_7 + out_9

        se_out = self.se_block(sspcab_out, self.filters, self.reduction_ratio)
        
        cost_sspcab = tf.square(inputs - se_out)
        loss = 0.1 * tf.reduce_mean(cost_sspcab)
                
        self.add_loss(loss)

        return se_out

# %%
#Size of our input images
SIZE = 128

from keras.preprocessing.image import ImageDataGenerator

batch_size = 32
datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_directory(
    'datasets/pill/train/',
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    class_mode='input'
    )

validation_generator = datagen.flow_from_directory(
    'datasets/pill/test/good',
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    class_mode='input'
    )

anomaly_generator = datagen.flow_from_directory(
    'datasets/pill/test/defective/',
    target_size=(SIZE, SIZE),
    batch_size=batch_size,
    class_mode='input'
    )
# Out:
# Found 267 images belonging to 1 classes.
# Found 26 images belonging to 1 classes.
# Found 141 images belonging to 7 classes.

# %% [markdown]
# ### Building the basic encoder

# %%
model = Sequential()

# Encoder 
"""
Each encoder is composed of three convolutional (conv)
layers, each followed by a max-pooling layer with a filter
size of 2 × 2 applied at a stride of 2. The conv layers are
formed of 3 × 3 filters. Each conv layer is followed by
Rectified Linear Units (ReLU) [70] as the activation function.
The first two conv layers consist of 32 filters, while the
third layer consists of 16 filters. The latent representation
is composed of 16 activation maps of size 8 × 8.
"""

model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(SIZE, SIZE, 3)))
model.add(MaxPooling2D((2, 2), padding='same', strides=2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same', strides=2))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))

# Decoder
"""
Each decoder starts with an upsampling layer, increasing
the spatial support of the activation maps by a factor of
2×. The upsampling operation is based on nearest neighbor
interpolation. After upsampling, we apply a conv layer with
16 filters of 3 × 3. The first upsampling and conv block
is followed by another two upsampling and conv blocks.
The last conv layer of an appearance decoder is formed of
a single conv filter, while the last conv layer of a motion
decoder is formed of two filters. In both cases, the number
of filters in the last conv layer is chosen such that the size of
the output matches the size of the input
"""
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(SSPCAB(name='sspcab', filters=64, kernel_dim=1, dilation=1, reduction_ratio=8))
model.add(Conv2D(3, (3, 3), activation='sigmoid', padding='same'))

# %% [markdown]
# ### Training the encoder

# %%
# Start with adam optimizer
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])

# %%
#Fit the model. 
history = model.fit(
        train_generator,
        steps_per_epoch= 267 // batch_size,
        epochs=10,
        shuffle = True)
# Out:
# Epoch 1/10
# C:\Users\madhu\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\structured_function.py:256: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 8/8 [==============================] - 45s 5s/step - loss: 0.1171 - mse: 0.1170
# Epoch 2/10
# 8/8 [==============================] - 46s 6s/step - loss: 0.0477 - mse: 0.0422
# Epoch 3/10
# 8/8 [==============================] - 43s 6s/step - loss: 0.0131 - mse: 0.0069
# Epoch 4/10
# 8/8 [==============================] - 45s 5s/step - loss: 0.0073 - mse: 0.0039
# Epoch 5/10
# 8/8 [==============================] - 44s 5s/step - loss: 0.0053 - mse: 0.0031
# Epoch 6/10
# 8/8 [==============================] - 44s 5s/step - loss: 0.0041 - mse: 0.0025
# Epoch 7/10
# 8/8 [==============================] - 43s 5s/step - loss: 0.0034 - mse: 0.0022
# Epoch 8/10
# 8/8 [==============================] - 44s 5s/step - loss: 0.0030 - mse: 0.0020
# Epoch 9/10
# 8/8 [==============================] - 42s 5s/step - loss: 0.0026 - mse: 0.0018
# Epoch 10/10
# 8/8 [==============================] - 43s 5s/step - loss: 0.0023 - mse: 0.0017

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['mse']
mse = history.history['loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, mse, 'r', label='MSE')
plt.title('Training and MSE')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# plt.plot(history.history['mse'])
# plt.plot(history.history['loss'])
# plt.title('Training and mse')
# plt.ylabel('loss')
# plt.xlabel('epochs')
# plt.legend(['training loss', 'val loss'], loc='upper left')
# plt.show()

# %%
#Save model
model.save('models/pill/autoencoder_pill.h5')

# %% [markdown]
# ### Load the trained model

# %%
tf.data.experimental.enable_debug_mode()

model = tf.keras.models.load_model('models/pill/autoencoder_pill.h5', custom_objects={'SSPCAB': SSPCAB})

# %%
# Get all batches generated by the datagen and pick a batch for prediction
#Just to test the model. 
data_batch = []  #Capture all training batches as a numpy array
img_num = 0
while img_num <= train_generator.batch_index:   #gets each generated batch of size batch_size
    data = train_generator.next()
    data_batch.append(data[0])
    img_num = img_num + 1

predicted = model.predict(data_batch[0])  #Predict on the first batch of images
# Out:
# 1/1 [==============================] - 1s 1s/step

# %% [markdown]
# ### Checking how the autoecoder works

# %%
#Sanity check, view few images and corresponding reconstructions
image_number = random.randint(0, predicted.shape[0])
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(data_batch[0][image_number])
plt.subplot(122)
plt.imshow(predicted[image_number])
plt.show()

# %% [markdown]
# ### Checking the reconstruction error

# %%
#Let us examine the reconstruction error between our validation data (good/normal images)
# and the anomaly images
validation_error = model.evaluate(validation_generator)
anomaly_error = model.evaluate(anomaly_generator)


print("Recon. error for the validation (normal) data is: ", validation_error)
print("Recon. error for the anomaly data is: ", anomaly_error)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.0022 - mse: 0.0016
# 5/5 [==============================] - 10s 2s/step - loss: 0.0024 - mse: 0.0018
# Recon. error for the validation (normal) data is:  [0.0021669664420187473, 0.0015787611482664943]
# Recon. error for the anomaly data is:  [0.002364288317039609, 0.0018155574798583984]

# %% [markdown]
# ### Building a feature extractor from the trained autoencoder

# %%
#Let us extract (or build) the encoder network, with trained weights.
#This is used to get the compressed output (latent space) of the input image. 
#The compressed output is then used to calculate the KDE

encoder_model = Sequential()

encoder_model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(SIZE, SIZE, 3),  trainable=False, weights=model.layers[0].get_weights()))
encoder_model.add(MaxPooling2D((2, 2), padding='same', strides=2))
encoder_model.add(Conv2D(32, (3, 3), activation='relu', padding='same', trainable=False, weights=model.layers[2].get_weights()))
encoder_model.add(MaxPooling2D((2, 2), padding='same', strides=2))
encoder_model.add(Conv2D(16, (3, 3), activation='relu', padding='same', trainable=False, weights=model.layers[4].get_weights()))

encoder_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 128, 128, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 32)        9248
#
#  max_pooling2d_3 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 16)        4624
#
# =================================================================
# Total params: 14,768
# Trainable params: 0
# Non-trainable params: 14,768
# _________________________________________________________________

# %%
# import sys
# !{sys.executable} -m pip install sklearn

# %%
# Calculate KDE using sklearn

from sklearn.neighbors import KernelDensity

#Get encoded output of input images = Latent space
encoded_images = encoder_model.predict(train_generator)

# Flatten the encoder output because KDE from sklearn takes 1D vectors as input
encoder_output_shape = encoder_model.output_shape #Here, we have 16x16x16
out_vector_shape = encoder_output_shape[1]*encoder_output_shape[2]*encoder_output_shape[3]

encoded_images_vector = [np.reshape(img, (out_vector_shape)) for img in encoded_images]

#Fit KDE to the image latent data
kde = KernelDensity(kernel='gaussian', bandwidth=0.2).fit(encoded_images_vector)
# Out:
# 9/9 [==============================] - 8s 828ms/step

# %% [markdown]
# ### Calculate Density & Recon Error to find the best threshold

# %%
#Calculate density and reconstruction error to find their means values for
#good and anomaly images. 
#We use these mean and sigma to set thresholds. 
def calc_density_and_recon_error(batch_images):
    density_list=[]
    recon_error_list=[]
    for im in range(0, batch_images.shape[0]-1):
        
        img  = batch_images[im]
        img = img[np.newaxis, :,:,:]
        encoded_img = encoder_model.predict([[img]]) # Create a compressed version of the image using the encoder
        encoded_img = [np.reshape(img, (out_vector_shape)) for img in encoded_img] # Flatten the compressed image
        density = kde.score_samples(encoded_img)[0] # get a density score for the new image
        reconstruction = model.predict([[img]])
        reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)[0]
        density_list.append(density)
        recon_error_list.append(reconstruction_error)
        
    average_density = np.mean(np.array(density_list))  
    stdev_density = np.std(np.array(density_list)) 
    
    average_recon_error = np.mean(np.array(recon_error_list))  
    stdev_recon_error = np.std(np.array(recon_error_list)) 
    
    return average_density, stdev_density, average_recon_error, stdev_recon_error

# %%
#Get average and std dev. of density and recon. error for uninfected and anomaly (parasited) images. 
#For this let us generate a batch of images for each. 
train_batch = train_generator.next()[0]
anomaly_batch = anomaly_generator.next()[0]

normal_values = calc_density_and_recon_error(train_batch)
anomaly_values = calc_density_and_recon_error(anomaly_batch)

print("Normal values: ", normal_values)
print("Anomaly values: ", anomaly_values)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0030 - mse: 0.0024
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0030 - mse: 0.0024
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0031 - mse: 0.0025
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0023 - mse: 0.0017
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0023 - mse: 0.0018
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0031 - mse: 0.0024
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 145ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0058 - mse: 0.0052
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0033 - mse: 0.0028
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0035 - mse: 0.0030
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0033 - mse: 0.0028
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0104 - mse: 0.0100
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0030 - mse: 0.0024
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0033 - mse: 0.0028
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0101 - mse: 0.0097
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0030 - mse: 0.0024
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0044 - mse: 0.0039
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0031 - mse: 0.0026
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 143ms/step - loss: 0.0029 - mse: 0.0024
# Normal values:  (11307.558670427881, 0.004220972095293839, 0.00274247745232236, 0.00021871997293221237)
# Anomaly values:  (11285.011742607829, 34.84753679133855, 0.003585001949461237, 0.0018489119651045878)

# %%
#Now, input unknown images and sort as Good or Anomaly
# Also, display the images where the model predicts an anomaly

# Normal values:  (11307.173204610757, 0.00021034008735510042, 0.0010616554852364765, 0.0004691525145013336)
# Anomaly values:  (11281.388645922418, 18.430181872661812, 0.0022931333214435126, 0.00189302380217782)

density_threshold = 11305 #Set this value based on the above exercise
reconstruction_error_threshold = 0.005# Set this value based on the above exercise

def check_anomaly(img_path):
    img  = Image.open(img_path)
    img = np.array(img.resize((128,128), Image.Resampling.LANCZOS))
    
    original_img = img.copy()
    
    img = img / 255.
    img = img[np.newaxis, :,:,:]
    
    encoded_img = encoder_model.predict([[img]]) 
    encoded_img = [np.reshape(img, (out_vector_shape)) for img in encoded_img] 
    
    density = kde.score_samples(encoded_img)[0] 

    reconstruction = model.predict([[img]])
    
    reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)[0]

    reconstruction_loss = np.abs(img - reconstruction)
    reconstruction_loss = np.mean(reconstruction_loss, axis=3)[0]
    
    return (density < density_threshold or reconstruction_error > reconstruction_error_threshold), original_img

# %% [markdown]
# ### Sanity Check and testing the model

# %%
#Load a couple of test images and verify whether they are reported as anomalies.
import glob
defective_file_paths = glob.glob('datasets/pill/test/defective/**/*')
normal_file_paths = glob.glob('datasets/pill/train/**/*')

tf.data.experimental.enable_debug_mode()

# %%
import PIL
from PIL import Image
if not hasattr(PIL.Image, 'Resampling'):  # Pillow<9.0
    PIL.Image.Resampling = PIL.Image
for _ in range(3):
    # test images
    random_img = np.random.randint(0, len(defective_file_paths))
    is_anomaly, original_img = check_anomaly(defective_file_paths[random_img])

    random_img2 = np.random.randint(0, len(normal_file_paths))
    is_anomaly2, original_img2 = check_anomaly(normal_file_paths[random_img])

    fig, ax = plt.subplots(1,2, figsize=(10,10))

    ax[0].imshow(original_img)
    ax[0].set_title("Anomaly" if is_anomaly else "Good")
    
    # add an overlay 
    

    ax[1].imshow(original_img2)
    ax[1].set_title("Anomaly" if is_anomaly2 else "Good")
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 146ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0027 - mse: 0.0022

# %% [markdown]
# ### Calculating the AUROC for the model

# %%
def roc_auc_score(y_true, y_pred):
    return np.mean(np.array(y_true) == np.array(y_pred))

def calc_auroc():
    y_true = []
    y_pred = []
    for f in defective_file_paths:
        is_anomaly, _ = check_anomaly(f)
        y_true.append(1)
        y_pred.append(is_anomaly)
        
    for f in normal_file_paths:
        is_anomaly, _ = check_anomaly(f)
        y_true.append(0)
        y_pred.append(is_anomaly)
        
    return roc_auc_score(y_true, y_pred)

print("AUROC: ", calc_auroc())
# Out:
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 153ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 139ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 145ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0030 - mse: 0.0024
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0030 - mse: 0.0024
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0027 - mse: 0.0023
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0034 - mse: 0.0030
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0035 - mse: 0.0030
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0034 - mse: 0.0029
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0031 - mse: 0.0027
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0037 - mse: 0.0032
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0032 - mse: 0.0028
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0034 - mse: 0.0029
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0035 - mse: 0.0030
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0035 - mse: 0.0030
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0043 - mse: 0.0038
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0042 - mse: 0.0038
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0043 - mse: 0.0038
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0041 - mse: 0.0036
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0032 - mse: 0.0026
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0031 - mse: 0.0025
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0031 - mse: 0.0026
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0031 - mse: 0.0025
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0031 - mse: 0.0026
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0028 - mse: 0.0024
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0031 - mse: 0.0025
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0033 - mse: 0.0028
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0032 - mse: 0.0026
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 141ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 149ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0031 - mse: 0.0025
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0051 - mse: 0.0045
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 168ms/step - loss: 0.0086 - mse: 0.0081
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0033 - mse: 0.0027
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0093 - mse: 0.0089
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0109 - mse: 0.0105
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0030 - mse: 0.0024
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0032 - mse: 0.0026
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0033 - mse: 0.0028
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0035 - mse: 0.0030
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0032 - mse: 0.0028
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0023 - mse: 0.0017
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0022 - mse: 0.0016
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 157ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 141ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0023 - mse: 0.0018
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 137ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 143ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 141ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0023 - mse: 0.0018
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0031 - mse: 0.0026
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 161ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 141ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0031 - mse: 0.0026
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0032 - mse: 0.0026
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0033 - mse: 0.0028
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0030 - mse: 0.0025
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 189ms/step - loss: 0.0023 - mse: 0.0017
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0022 - mse: 0.0017
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0032 - mse: 0.0027
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 149ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0033 - mse: 0.0027
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 177ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0031 - mse: 0.0025
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 172ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 148ms/step - loss: 0.0031 - mse: 0.0026
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 172ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0033 - mse: 0.0028
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 173ms/step - loss: 0.0031 - mse: 0.0026
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 137ms/step
# ...
# 1/1 [==============================] - 0s 160ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 158ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 169ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 148ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 161ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 172ms/step - loss: 0.0030 - mse: 0.0024
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 211ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 162ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 167ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 163ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 172ms/step - loss: 0.0030 - mse: 0.0024
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 180ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 193ms/step - loss: 0.0028 - mse: 0.0022
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 165ms/step - loss: 0.0029 - mse: 0.0022
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 160ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0023 - mse: 0.0018
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 180ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 162ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 193ms/step - loss: 0.0023 - mse: 0.0017
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 149ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 177ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 171ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 203ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 159ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 193ms/step - loss: 0.0023 - mse: 0.0018
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 171ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 218ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 201ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0023 - mse: 0.0018
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 158ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 163ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 167ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 172ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 161ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 174ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 165ms/step - loss: 0.0027 - mse: 0.0021
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 158ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 191ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 200ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0023 - mse: 0.0017
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 179ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0023 - mse: 0.0017
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 188ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 164ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 190ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 176ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 183ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 195ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 222ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 203ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 189ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 176ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 176ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0025 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 207ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 209ms/step - loss: 0.0026 - mse: 0.0021
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 189ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 199ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 221ms/step - loss: 0.0029 - mse: 0.0023
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 199ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 174ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 189ms/step - loss: 0.0023 - mse: 0.0018
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 226ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 215ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 174ms/step - loss: 0.0026 - mse: 0.0020
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 195ms/step - loss: 0.0023 - mse: 0.0017
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 189ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 202ms/step - loss: 0.0024 - mse: 0.0019
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0026 - mse: 0.0021
# AUROC:  1.0

# %% [markdown]
# ### Let's see if the model is able to localize the anomalies

# %%
import cv2

reconstruction_error_threshold = 0.001

def check_anomaly_localization(img_path):
    img  = Image.open(img_path)
    img = np.array(img.resize((128,128), Image.Resampling.LANCZOS))
    
    original_img = img.copy()
    
    img = img / 255.
    img = img[np.newaxis, :,:,:]
    
    encoded_img = encoder_model.predict([[img]]) 
    encoded_img = [np.reshape(img, (out_vector_shape)) for img in encoded_img] 
    
    density = kde.score_samples(encoded_img)[0] 

    reconstruction = model.predict([[img]])
    
    
    
    reconstruction_error = model.evaluate([reconstruction],[[img]], batch_size = 1)
        
    reconstruction_error = reconstruction_error[1]

    reconstruction_loss = np.abs(img - reconstruction)
    reconstruction_loss = np.mean(reconstruction_loss, axis=3)[0]
    
    # add a mask of the reconstruction loss as a heatmap
    mask = reconstruction_loss > 0.1
    overlay = original_img.copy()
    overlay[mask] = [255, 0, 0]
    
    # join close regions of the mask, and remove sparse pixels
    new_overlay = np.zeros_like(overlay)
    new_overlay = cv2.morphologyEx(overlay, cv2.MORPH_CLOSE, np.ones((5,5), np.uint8))
    
    
    # remove small regions of the mask that are not part of the anomaly
    contours, _ = cv2.findContours(new_overlay[:,:,1], cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    
    for cnt in contours:
        if cv2.contourArea(cnt) < 75:
            cv2.drawContours(new_overlay, [cnt], -1, (0,0,0), -1)
            
    return (density < density_threshold or reconstruction_error > reconstruction_error_threshold), original_img, new_overlay

# %%
file_paths = defective_file_paths

for _ in range(10):
    # test images
    random_img = np.random.randint(0, len(file_paths))
    
    random_img = file_paths[random_img]
    
    image_name = random_img.split('/')[-1]
    image_name = image_name.split("\\")[-2:]
    image_name = '/'.join(image_name) 
    
    # remove the .png extension
    image_name = image_name[:-4]
    
    # add _mask.png
    image_name += '_mask.png'
    
    original_path = 'datasets/pill'
    
    gt = Image.open(f'{original_path}/ground_truth/{image_name}').convert('RGBA').resize((128,128), Image.Resampling.LANCZOS)
    

    is_anomaly, original_img, mask = check_anomaly_localization(random_img)

    fig, ax = plt.subplots(1,3, figsize=(10,4))
    
    fig.suptitle("Anomaly" if is_anomaly else "Good")
    
    ax[0].imshow(original_img)
    ax[0].set_title("Original")
    
    ax[1].imshow(original_img)

    
    ax[1].imshow(mask, alpha=1)
    ax[1].set_title("Localization")
    
    ax[2].imshow(original_img)
    
    gt = np.array(gt)
    
    a = np.zeros_like(gt)
    a[gt[:,:,0] > 0] = [0, 0,255, 255]
    
    ax[2].imshow(a, alpha=1)
    ax[2].imshow(mask, alpha=0.5)
    ax[2].set_title("Ground Truth")
    
    
    plt.show()
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 337ms/step - loss: 0.0025 - mse: 0.0019
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 321ms/step - loss: 0.0033 - mse: 0.0028
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 355ms/step - loss: 0.0023 - mse: 0.0018
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 286ms/step
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0028 - mse: 0.0023
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 289ms/step
# 1/1 [==============================] - 0s 262ms/step - loss: 0.0024 - mse: 0.0018
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 310ms/step - loss: 0.0032 - mse: 0.0026
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 242ms/step - loss: 0.0029 - mse: 0.0024
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 301ms/step
# 1/1 [==============================] - 0s 319ms/step - loss: 0.0027 - mse: 0.0022
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 283ms/step
# 1/1 [==============================] - 0s 253ms/step - loss: 0.0034 - mse: 0.0029
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 332ms/step - loss: 0.0028 - mse: 0.0023
